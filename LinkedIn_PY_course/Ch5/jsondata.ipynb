# %%
import urllib.request
import json

# %%
#  Example file for parsing and processing JSON
#
def printResults(data):
  # Use the json module to load the string data into a dictionary
  theJSON = json.loads(data)
  
  # now we can access the contents of the JSON like any other Python object
  if "title" in theJSON["metadata"]:
    print(theJSON["metadata"]["title"])
  
  # output the number of events, plus the magnitude and each event name  
  count = theJSON["metadata"]["count"]
  print(str(count) + " events recorded")

  
  # for each event, print the place where it occurred
  for i in theJSON["features"]:
    print(i["properties"]["place"])
  print("--------------------\n")
  
  # print the events that only have a magnitude greater than 4

  for i in theJSON["features"]:
    if i["properties"]["mag"] >= 4.0:
      print("%2.1f" % i["properties"]["mag"], i["properties"]["place"])
  print("--------------------\n")
  
# print only the events where at least 1 person reported feeling something
  print("Events that were felt: ")
  for i in theJSON["features"]:
    feltReports = i["properties"]["felt"]
    if feltReports != None:
      if feltReports > 0:
        print("%2.1f" % i["properties"]["mag"], i["properties"]["place"], 
        " reported " + str(feltReports) + " times")

# %%
  

  # define a variable to hold the source URL
  # In this case we'll use the free data feed from the USGS
  # This feed lists all earthquakes for the last day larger than Mag 2.5
  urlData = "http://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/2.5_day.geojson"

  # Open the URL and read the data
  webUrl = urllib.request.urlopen(urlData)
  print ("result code: " + str(webUrl.getcode()))
  if (webUrl.getcode() == 200):
    data = webUrl.read()
    printResults(data)
  else:
    print("received errror)")
# Out:
# result code: 200
# USGS Magnitude 2.5+ Earthquakes, Past Day
# 56 events recorded
# 28km SSW of Smith Valley, NV
# 28 km SSE of Mazo Cruz, Peru
# 8 km SW of Volcano, Hawaii
# 5 km SSE of Pāhala, Hawaii
# 3 km N of Hallettsville, Texas
# 54 km SE of Nikolski, Alaska
# 36 km SW of Callao, Peru
# 109 km S of Naze, Japan
# 10 km SSE of Maria Antonia, Puerto Rico
# 86 km N of San Antonio, Puerto Rico
# 5 km SW of Volcano, Hawaii
# 117 km W of San Antonio de los Cobres, Argentina
# 9 km ENE of Pāhala, Hawaii
# South Sandwich Islands region
# 198 km SE of Sarangani, Philippines
# 51 km W of Mentone, Texas
# 3 km SSE of Maria Antonia, Puerto Rico
# 244 km S of Sinabang, Indonesia
# 3 km ENE of Pāhala, Hawaii
# 5 km SW of Volcano, Hawaii
# 34 km NW of Villa Basilio Nievas, Argentina
# 113 km ENE of Sarāhan, India
# 45 km WSW of Kaktovik, Alaska
# 154 km WSW of Ovalle, Chile
# 99 km SSW of Nueva Concepción, Guatemala
# 81 km N of Charlotte Amalie, U.S. Virgin Islands
# 1 km S of Quinton, Oklahoma
# South Sandwich Islands region
# 70 km SSE of Inarajan Village, Guam
# 244 km E of Levuka, Fiji
# 85 km S of Severo-Kuril’sk, Russia
# Kepulauan Babar, Indonesia
# Izu Islands, Japan region
# 116 km SSW of Kaktovik, Alaska
# 6 km WSW of Volcano, Hawaii
# Mona Passage
# 108 km E of Iquique, Chile
# western Honshu, Japan
# 22 km N of Pāhala, Hawaii
# 7 km SW of Volcano, Hawaii
# 83 km S of Champerico, Guatemala
# 17 km WNW of Palca, Peru
# 36 km N of Guanaja, Honduras
# Kepulauan Babar, Indonesia
# 3 km SE of La Parguera, Puerto Rico
# South Sandwich Islands region
# 257 km SSE of Rāzole, India
# 12km W of Delta, B.C., MX
# 223 km SSW of Severo-Kuril’sk, Russia
# 6 km SE of Pole Ojea, Puerto Rico
# 4 km SE of La Parguera, Puerto Rico
# 87 km NW of San Antonio, Puerto Rico
# 4 km SE of La Parguera, Puerto Rico
# 118 km WSW of Myitkyina, Myanmar
# 38 km N of San Juan, Puerto Rico
# 15 km SSE of Guánica, Puerto Rico
# --------------------
#
# 4.2 28 km SSE of Mazo Cruz, Peru
# 4.2 54 km SE of Nikolski, Alaska
# 4.4 36 km SW of Callao, Peru
# 5.0 109 km S of Naze, Japan
# 4.3 117 km W of San Antonio de los Cobres, Argentina
# 5.0 South Sandwich Islands region
# 4.5 198 km SE of Sarangani, Philippines
# 4.9 244 km S of Sinabang, Indonesia
# 4.3 34 km NW of Villa Basilio Nievas, Argentina
# 4.7 113 km ENE of Sarāhan, India
# 4.3 154 km WSW of Ovalle, Chile
# 5.6 99 km SSW of Nueva Concepción, Guatemala
# 4.9 South Sandwich Islands region
# 5.4 70 km SSE of Inarajan Village, Guam
# 4.4 244 km E of Levuka, Fiji
# 4.4 85 km S of Severo-Kuril’sk, Russia
# 4.3 Kepulauan Babar, Indonesia
# 4.9 Izu Islands, Japan region
# 4.1 108 km E of Iquique, Chile
# 4.2 western Honshu, Japan
# 4.0 83 km S of Champerico, Guatemala
# 4.4 17 km WNW of Palca, Peru
# 4.6 36 km N of Guanaja, Honduras
# 4.4 Kepulauan Babar, Indonesia
# 5.2 South Sandwich Islands region
# 5.1 257 km SSE of Rāzole, India
# 6.0 223 km SSW of Severo-Kuril’sk, Russia
# 4.6 118 km WSW of Myitkyina, Myanmar
# --------------------
#
# Events that were felt:
# 2.7 3 km N of Hallettsville, Texas  reported 1 times
# 4.4 36 km SW of Callao, Peru  reported 4 times
# 3.7 1 km S of Quinton, Oklahoma  reported 26 times
# 5.4 70 km SSE of Inarajan Village, Guam  reported 9 times
# 3.4 6 km WSW of Volcano, Hawaii  reported 1 times
# 4.1 108 km E of Iquique, Chile  reported 3 times
# 4.4 17 km WNW of Palca, Peru  reported 1 times
# 4.6 36 km N of Guanaja, Honduras  reported 2 times
# 5.1 257 km SSE of Rāzole, India  reported 25 times
# 6.0 223 km SSW of Severo-Kuril’sk, Russia  reported 2 times
# 3.3 4 km SE of La Parguera, Puerto Rico  reported 1 times
# 2.5 4 km SE of La Parguera, Puerto Rico  reported 2 times
# 3.2 38 km N of San Juan, Puerto Rico  reported 1 times
