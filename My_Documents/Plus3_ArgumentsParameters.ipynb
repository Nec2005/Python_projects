# %%
def who(first, last) :  # 'first' and 'last' are the parameters(or variables)
    print('Your first name is :', first)
    print('Your last name is :', last)

who('Guido', 'van Rossum')  # 'Guido' and 'van Rossum' are the arguments
print()
who('Marry', 'Bold')  # 'Marry' and 'Bold' are also the arguments

# %%
def pos_args(a, b):
    print(a, 'is the first argument')
    print(b, 'is the second argument')

pos_args(3,4)
print()
pos_args(4,3)
# Out:
# 3 is the first argument
# 4 is the second argument
#
# 4 is the first argument
# 3 is the second argument

# %%
pos_args([1, 2, '23'], {234, 'ag'})
# Out:
# [1, 2, '23'] is the first argument
# {234, 'ag'} is the second argument

# %%
def texter(x, y, z) :
    return f"{y} {z} {x}"

# %%
x = 'i'
y = 'love'
z = 'you'
texter(z, x, y)
# Out:
# 'i love you'

# %%
texter(y, z, x)
# Out:
# 'you i love'

# %%
def who(first, last) :  # same structure as the previous one
	print('Your first name is :', first)
	print('Your last name is :', last)
	
who(first='Guido', last='van Rossum')  # calling the function is different
# we used kwargs to pass the values into the function
# Out:
# Your first name is : Guido
# Your last name is : van Rossum

# %%
def who(first, last) :  # same structure as the previous one
	print('Your first name is :', first)
	print('Your last name is :', last)
	
who(last='van Rossum', first='Guido')  # calling the function is different
# we used kwargs to pass the values into the function
# Out:
# Your first name is : Guido
# Your last name is : van Rossum

# %%
def concat(a, b) :
    print(a + b)

# %%
concat(b = 'ali ', a = 'veli ')
# Out:
# veli ali

# %%
def texter(text1, text2, text3):
    print(f"{text2} {text3} {text1}")

texter(text1='you', text2='i', text3='love')
texter(text2='i', text3='love', text1='you')
# Out:
# i love you
# i love you

# %%
def default(a = 'ali', b = 33):
    print(a, 'is', b, 'years old')

# %%
default()
# Out:
# ali is 33 years old

# %%
default('mehmet', 44)
# Out:
# mehmet is 44 years old

# %%
default(b = 55)
# Out:
# ali is 55 years old

# %%
default(a = 'songul', b = 23)
# Out:
# songul is 23 years old

# %%
def default(x, a = 'ali', b = 33):
    print(a, 'and', x, 'is', b, 'years old')

# %%
default('veli')
# Out:
# ali and veli is 33 years old

# %%
def parrot(voltage, state='a stiff', action='voom', typed='Norwegian Blue'):
    print("-- This parrot wouldn't", action, end=' ')
    print("if you put", voltage, "volts through it.")
    print("-- Lovely plumage, the", typed)
    print("-- It's", state, "!")

parrot(12)
# Out:
# -- This parrot wouldn't voom if you put 12 volts through it.
# -- Lovely plumage, the Norwegian Blue
# -- It's a stiff !

# %%
parrot(235)
# Out:
# -- This parrot wouldn't voom if you put 235 volts through it.
# -- Lovely plumage, the Norwegian Blue
# -- It's a stiff !

# %%
parrot(voltage = 500000, action = 'VOOOOOOOOM')
# Out:
# -- This parrot wouldn't VOOOOOOOOM if you put 500000 volts through it.
# -- Lovely plumage, the Norwegian Blue
# -- It's a stiff !

# %%
parrot(action = 'VOOOOOOOOM', voltage = 500000, )
# Out:
# -- This parrot wouldn't VOOOOOOOOM if you put 500000 volts through it.
# -- Lovely plumage, the Norwegian Blue
# -- It's a stiff !

# %%
parrot('a million', 'bereft of life', 'jump') ## soldan saga sirayla atadi
# Out:
# -- This parrot wouldn't jump if you put a million volts through it.
# -- Lovely plumage, the Norwegian Blue
# -- It's bereft of life !

# %%
def parrot(state='a stiff', voltage, action='voom', typed='Norwegian Blue'):
    print("-- This parrot wouldn't", action, end=' ')
    print("if you put", voltage, "volts through it.")
    print("-- Lovely plumage, the", typed)
    print("-- It's", state, "!")
# Out:
#   File "<ipython-input-42-a04a5095d128>", line 1
#     def parrot(state='a stiff', voltage, action='voom', typed='Norwegian Blue'):
#               ^
# SyntaxError: non-default argument follows default argument

# %%
def argu(a, b = 'dunya', c, d = 'saturn') : ##once positionlar gelecek
    print( a, b, c, d, sep = "\n")
# Out:
#   File "<ipython-input-43-76a9e83e04e6>", line 1
#     def argu(a, b = 'dunya', c, d = 'saturn') :
#             ^
# SyntaxError: non-default argument follows default argument

# %%
def argu(a, c, b = 'dunya', d = 'saturn') : ##once positionlar gelecek
    print( a, b, c, d, sep = "\n")

# %%
argu('uranus', 'jupiter')
# Out:
# uranus
# dunya
# jupiter
# saturn

# %%
def city(capital, continent='Europe'):
    print(capital, 'in', continent)

city('Athens')  # we don't have to pass any arguments into 'continent'
city('Ulaanbaatar', continent='Asia')  # we can change the default value by kwargs
city('Cape Town', 'Africa')  # we can change the default value by positional args.

# %%
def fruiterer(fruit1, fruit2):
    print('I want to', fruit1, 'and', fruit2)

fruiterer('orange', 'banana')
# Out:
# I want to orange and banana

# %%
def fruiterer(*fruit) :
    print('I want to get :')
    for i in fruit :
        print('-', i)
        
fruiterer('orange', 'banana', 'melon', 'ananas')
# Out:
# I want to get :
# - orange
# - banana
# - melon
# - ananas

# %%
meyv = ['orange', 'banana', 'melon']
fruiterer(meyv)
# Out:
# I want to get :
# - ['orange', 'banana', 'melon']

# %%
def function(a):
    pass  # actually, 'pass' does nothing. it just moves to the next line 
       # of code

# %%
function(57)

# %%
def slicer(*num) :
    evens = []
    odds = []
    for i in num:
        if i % 2 :
            odds.append(i)
        else :
            evens.append(i)
    print('odd list :', odds)
    print('even list :', evens)

# %%
slicer(2, 5, 8, 9, 23, 11, 7, 4)
# Out:
# odd list : [5, 9, 23, 11, 7]
# even list : [2, 8, 4]

# %%
def slicer(*num):
    print('evens:', [i for i in num if i%2 == 0])
    print('odd:', [i for i in num if not i%2 == 0])

# %%
slicer(1, 2, 3, 4, 5, 6, 7, 8, 9)
# Out:
# evens: [2, 4, 6, 8]
# odd: [1, 3, 5, 7, 9]

# %%
def default(a = 'ali', b = 33):
    print(a, 'is', b, 'years old')

# %%
def animals(**kwargs):
    for key, value in kwargs.items():
        print(value, "are", key)
 
animals(Carnivores="Lions", Omnivores="Bears", Herbivores="Deers", Nomnivores="Human")
# Out:
# Lions are Carnivores
# Bears are Omnivores
# Deers are Herbivores
# Human are Nomnivores

# %%
animals(Carnivores="Lions", Omnivores="Bears", Herbivores="Deers", Nomnivores="Human")
# Out:
# Lions are Carnivores
# Bears are Omnivores
# Deers are Herbivores
# Human are Nomnivores

# %%
def brothers(bro1, bro2, bro3):
    print('Here are the names of brothers :')
    print(bro1, bro2, bro3, sep='\n')

family = ['tom', 'sue', 'tim']
brothers(*family)
# Out:
# Here are the names of brothers :
# tom
# sue
# tim

# %% [markdown]
# **kwargs dict gibi muamele gorur

# %%
sozluk = dict(ahmet = 'bacanak', mehmet = 'agabey', ceyda = 'baldiz', meryem = 'anne')

# %%
sozluk
# Out:
# {'ahmet': 'bacanak', 'ceyda': 'baldiz', 'mehmet': 'agabey', 'meryem': 'anne'}

# %%
def sozluk(**a) :
    for key, value in a.items() :
        print(key, value)

# %%
sozluk(ahmet = 'bacanak', mehmet = 'agabey')
# Out:
# ahmet bacanak
# mehmet agabey

# %%
def organizer(**a) :
    for key, value in a. items() :
        print(a.keys())
        print(a.values())
        break

# %%
organizer(Beth = 26, Oscar = 42, Justin = 18 )
# Out:
# dict_keys(['Beth', 'Oscar', 'Justin'])
# dict_values([26, 42, 18])

# %%
def organizer(**people):
    names = []
    ages = []
    for key, value in people.items():
        names.append(key)
        ages.append(value)
    print(names, ages, sep ='\n')

# %%
organizer(Beth = 26, Oscar = 42, Justin = 18, ali = 48)
# Out:
# ['Beth', 'Oscar', 'Justin', 'ali']
# [26, 42, 18, 48]

# %%
def defa(**x):
    for t, z in x.items():
        print(t, 'is', z, 'years old')

# %%
defa( ali = 33, veli = 44, ayse = 33,  mehmet = 16)
# Out:
# ali is 33 years old
# veli is 44 years old
# ayse is 33 years old
# mehmet is 16 years old

# %%
def gene(x, y):  # defined by positional args
    print(x, "belongs to Generation X")
    print(y, "belongs to Generation Y")
 
dict_gene = {'y' : "Marry", 'x' : "Fred"}
gene(**dict_gene)  # we call the function by a single argument(variable)
# Out:
# Fred belongs to Generation X
# Marry belongs to Generation Y

# %%
def gene(x='Solomon', y='David'):  # defined by kwargs (default values assigned to x and y)
    print(x, "belongs to Generation X")
    print(y, "belongs to Generation Y")
 
dict_gene = {'y' : "Marry", 'x' : "Fred"}
gene(**dict_gene)
# Out:
# Fred belongs to Generation X
# Marry belongs to Generation Y
