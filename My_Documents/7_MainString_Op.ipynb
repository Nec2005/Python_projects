# %%
degisken1 = 'Clarusway'   #immutability ornek
print(degisken1.upper())
print(degisken1)
degisken1 = degisken1.upper() # yeni deger atayarak degistiriyoruz
print(degisken1)
# Out:
# CLARUSWAY
# Clarusway
# CLARUSWAY

# %%
sentence = "I live and work in Virginia"
print(sentence.upper())
print(sentence.lower())
print(sentence.swapcase()) # buyuk olan kucuk, kucuk olan buyuk
print(sentence)
# Out:
# I LIVE AND WORK IN VIRGINIA
# i live and work in virginia
# i LIVE AND WORK IN vIRGINIA
# I live and work in Virginia

# %%
sentence = "I live and work in Virginia"
title_sentence = sentence.title()
print(title_sentence)

changed_str = title_sentence.replace('i', '+')

print(changed_str)
# Out:
# I Live And Work In Virginia
# I L+ve And Work In V+rg+n+a

# %%
var_str = 'In God we Trust' #degisken degismedi
var_str.lower()
print(var_str)
# Out:
# In God we Trust

# %%
var_str = 'In God we Trust' #degisken degismedi
print(var_str.lower())
print(var_str)
# Out:
# in god we trust
# In God we Trust

# %%
text = "www.clarusway.com"
print(text.endswith('.com'))
print(text.startswith('http:'))
# Out:
# True
# False

# %%
phrase = 'What is Soul?'
print(phrase.upper().swapcase()) #swap buyugu kucuk kucugu buyuk yapiyor.
# Out:
# what is soul?

# %%
phrase = 'What is Soul?'
new_phrase= phrase.replace('Soul', 'feeliNGS')
print(new_phrase.title())
# Out:
# What Is Feelings?

# %%
text = "www.clarusway.com"
print(text.endswith('om'))
print(text.startswith('w'))
# Out:
# True
# True

# %%
text = "www.clarusway.com"
print(text.endswith('.co')) #son uc karaktere bakar
print(text.startswith('w.')) #ilk iki karaktere bakar
# Out:
# False
# False

# %%
capital = 1000
rate = 0.07
capital = capital+(capital*rate) #day1 profit 
print(capital)
capital += capital*0.07 #day2 profit
print(capital)
capital += capital*0.07 #day3 profit
capital += capital*0.07 #day4 profit
capital += capital*0.07 #day5 profit
capital += capital*0.07 #day6 profit
capital += capital*0.07 #day7 profit
capital
# Out:
# 1070.0
# 1144.9
# 1605.78147647843

# %%
capital = 1000
rate = 0.07
day7 = capital*((1+rate)**7)
print(day7)
# Out:
# 1605.7814764784307

# %%
derece = input('sicaklik gir') 
fahrenheit = (int(derece) *9)/5 + 32
print('Fahrenheit donusumu =',fahrenheit)
# Out:
# sicaklik gir25
# Fahrenheit donusumu = 77.0

# %%
age = input('is your age older than 75?:') 
cigarette = input ('Do you smoke:')
chronic = input ('Do you have a severe chronic disease:')
immune = input ('is your immune system too weak?:')
obesity = input ('Have you been diagnosed with obesity?:')
risk = (age and cigarette) or chronic or immune or obesity
print('Covid sonucu olum olasiligi = ', risk)
# Out:
# is your age older than 75?:y
# Do you smoke:n
# Do you have a severe chronic disease:y
# is your immune system too weak?:n
# Have you been diagnosed with obesity?:n
# Covid sonucu olum olasiligi =  n

# %%
text = 'the better the Family, the better the Society'
print(text)
print(text.capitalize())

text = text.swapcase()
print(text)
# Out:
# the better the Family, the better the Society
# The better the family, the better the society
# THE BETTER THE fAMILY, THE BETTER THE sOCIETY

# %%
text = 'S0d0me and G0m0re'
text = text.replace('0', 'o', 2)
text
# Out:
# 'Sodome and G0m0re'

# %%
ornek = "ee   ee    ee basinda ve sonunda bosluk olan cumle.  e      ee"

print(ornek)
print(ornek.strip())
print(ornek.strip('e'))
# Out:
# ee   ee    ee basinda ve sonunda bosluk olan cumle.  e      ee
# ee   ee    ee basinda ve sonunda bosluk olan cumle.  e      ee
#    ee    ee basinda ve sonunda bosluk olan cumle.  e

# %%
ornek = "interoperability" # basa ve sondaki karakterlare bakar

print(ornek.strip('yin'))
# Out:
# teroperabilit

# %%
ornek = "interoperability" 

print(ornek.lstrip('inyt')) # sadece soldaki  karakterlare bakar
# Out:
# eroperability

# %%
ornek = "interoperability" 

print(ornek.rstrip('inyt')) # sadece sagdaki  karakterlare bakar
# Out:
# interoperabil

# %%
ornek = "       basinda ve sonunda bosluk olan cumle...       "

print(ornek)
print(ornek.strip())
print(ornek.rstrip())
print(ornek.lstrip())
# Out:
#        basinda ve sonunda bosluk olan cumle...
# basinda ve sonunda bosluk olan cumle...
#        basinda ve sonunda bosluk olan cumle...
# basinda ve sonunda bosluk olan cumle...

# %%
text = 'tyou can learn almost everything in pre-classz'

print(text.strip('tz').upper())
# Out:
# YOU CAN LEARN ALMOST EVERYTHING IN PRE-CLASS

# %%
text = 'tyou can learn almost everything in pre-classz'
print(text.replace('t',''))  #
# Out:
# you can learn almos everyhing in pre-classz

# %%
text = 'In God wee Trust'
print(text.replace('e','',1).title())
print(text.replace("wee", "We"))
# Out:
# In God We Trust
# In God We Trust
