# %%
def moduler(n) :
      return n**2

# %%
lambda x : x**5
# Out:
# <function __main__.<lambda>>

# %%
uzeribes = lambda x : x**5

# %%
uzeribes(2)
# Out:
# 32

# %%
def modular_function(n):
    return lambda x: x ** n

power_of_2 = modular_function(2)  # first sub-function derived from def
power_of_3 = modular_function(3)  # second sub-function derived from def
power_of_4 = modular_function(4)  # third sub-function derived from def

print(power_of_2(2))  # 2 to the power of 2
print(power_of_3(2))  # 2 to the power of 3
print(power_of_4(2))  # 2 to the power of 4
# Out:
# 4
# 8
# 16

# %%
kupunual = modular_function(3)
kupunual(3)
# Out:
# 27

# %%
def repeater(n):  # tekrar ediyo, carpi, absteriks
    return lambda x: x * n

repeat_2_times = repeater(2)  # repeats 2 times
repeat_3_times = repeater(3)  # repeats 3 times
repeat_4_times = repeater(4)  # repeats 4 times

print(repeat_2_times('alex '))
print(repeat_3_times('lara '))
print(repeat_4_times('linda '))
# Out:
# alex alex
# lara lara lara
# linda linda linda linda

# %%
repeater(2)
print(repeater(3))
# Out:
# <function repeater.<locals>.<lambda> at 0x7fec85f35dd0>

# %%
tekrarlayici4 = lambda x : x * 4

# %%
tekrarlayici4('lara ')
# Out:
# 'lara lara lara lara '

# %%
def functioner (emoji = None) :
    return lambda message : print(message, emoji)

# %%
(lambda message : print(message, ':)'))(66)
# Out:
# 66 :)

# %%
print_smile = functioner(':)')
print_smile([66])
# Out:
# [66] :)

# %%
print_sad = functioner(":(")
print_sad('bugunku ders')
# Out:
# bugunku ders :(

# %%
def func_generator(func_name) :
    return lambda x : func_name(x)

# %%
ali_max = func_generator(max)
ali_max((1, 5, 9, 55))
# Out:
# 55

# %%
ali_sorted = func_generator(sorted)
ali_sorted([2, 9, 23, 45, 6])
# Out:
# [2, 6, 9, 23, 45]
