# %%
a = 1

print(-a)
# Out:
# -1

# %%
b = -11 # - ile carpiyormus gibi algiliyor
print(-b)
# Out:
# 11

# %%
a = 3
b = 4

print('The sum of {} + {} is :{}'.format(a, b, a+b))
# Out:
# The sum of 3 + 4 is :7

# %%
text = "{:.2f}, {:.3f}, {:.4f}".format(3.1463, 5.367, 7.324324)
print(text)
# Out:
# 3.15, 5.367, 7.3243

# %%
text = "{:.2s}, {:.3s}, {:.4s}".format('a3.1463', 'b5.367', 'c7.324324')
print(text)
# Out:
# a3, b5., c7.3

# %%
text = "{:.2}, {:.3}, {:.4}".format('a3.1463', 'b5.367', 'c7.324324')
print(text)
# Out:
# a3, b5., c7.3

# %%
text = "{:>10}".format("test") # 10 kRkterlik alanda sag yasla

text
# Out:
# '      test'

# %%
text = "{:<10}".format("test") # 10 kRkterlik alanda sola yasla

text
# Out:
# 'test      '

# %%
text = "formatlama satiri{:>20} bu da textin  sonu".format("test")
text
# Out:
# 'formatlama satiri                test bu da textin  sonu'

# %%
text = "bla bla {:<15} formatlama cumlecigi".format("okkes")
text
# Out:
# 'bla bla okkes           formatlama cumlecigi'

# %%
text = "{:^20}".format("abs") #20 karakterlik alanda ortalma
text
# Out:
# '        abs         '

# %%
"{:10.5}".format('hippopotamus')
# Out:
# 'hippo     '

# %%
"{:>15.5}".format("hippopotamus")
# Out:
# '          hippo'

# %%
"{:+d}".format(115) #
# Out:
# '+115'

# %%
age = False
chronic = False
immune = True

covid =  age or chronic or immune
covid
# Out:
# True
