# %%
def square(x):
    return x**2  ##user defined funct

# %%
lambda x: x**2
# Out:
# <function __main__.<lambda>>

# %%
lambda z: z%2 + z**3
# Out:
# <function __main__.<lambda>>

# %%
(lambda z: z%2 + z**3)(5)
# Out:
# 126

# %%
lambda x, y: (x+y)/2  # takes two numbers, returns the result

# %%
lambda x: 'odd' if x % 2 != 0 else 'even'

# %%
lambda x : 'odd' if x % 2 else 'even'

# %%
lambda x, y, z : 'Pisagor formulune uygun' if (x**2 + y**2)**0.5 == z else 'Pisagor formulune uygun'
# Out:
#   File "<ipython-input-13-0545ac732281>", line 1
#     lambda x, y, z : 'Pisagor formulune uygun' if (x**2 + y**2)**0.5 = z else 'Pisagor formulune uygun'
#                                                                      ^
# SyntaxError: invalid syntax

# %%
pisagor = lambda x, y, z : 'Pisagor formulune uygun' if (x**2 + y**2)**0.5 == z else 'Pisagor formulune uygun degil'

# %%
pisagor(7,8,10)
# Out:
# 'Pisagor formulune uygun degil'

# %%
(lambda x: x**2)(2)  # squares '2'##By enclosing the function in parentheses :
# Out:
# 4

# %%
(lambda x : 'odd' if x % 2 else 'even')(5)
###By enclosing the function in parentheses :
# Out:
# 'odd'

# %%
print((lambda x, y: (x+y)/2)(3, 5))  # takes two int, returns mean of them
# Out:
# 4.0

# %%
average = (lambda a, b : a**2 + b**2)(3, 5)
print(average)
# Out:
# 34

# %%
iterable = 'clarusway'
reverser = (lambda x : x[::-1])(iterable)

# %%
print(reverser)
# Out:
# yawsuralc

# %%
lambda x : i for i in x 'i : odd ' if i%2 else 'i : even'
# Out:
#   File "<ipython-input-15-edccd6cf3b4a>", line 1
#     lambda x : i for i in x 'i : odd ' if i%2 else 'i : even'
#                    ^
# SyntaxError: invalid syntax

# %%
list = [1, 2, 3, 4, 5, 6]
for i in list :
    oddeven= (lambda x : 'odd' if x % 2 else 'even')(i)
    print(i, ':', oddeven)
# Out:
# 1 : odd
# 2 : even
# 3 : odd
# 4 : even
# 5 : odd
# 6 : even

# %%
for i in [1, 2, 3, 4, 5, 6] :
    print(i, ':', (lambda x : "odd" if x%2 != 0 else "even")(i))
# Out:
# 1 : odd
# 2 : even
# 3 : odd
# 4 : even
# 5 : odd
# 6 : even

# %%
average = lambda x, y: (x+y)/2
print(average(3, 5))  # we call
# Out:
# 4.0

# %%
hipo = lambda a, b : a**2 + b**2
hipo(3, 4)
# Out:
# 25

# %%
iterable2 = 'clarusway'
reverser = lambda x : x[::-1]  ## degiskene atayarak cikti alma
print(reverser(iterable2))
# Out:
# yawsuralc

# %%
iterable = [1, 2, 3, 4, 5]
map(lambda x:x**2, iterable)
result = map(lambda x:x**2, iterable)
print(type(result))  # it's a map type

print(list(result))  # we've converted it to list type to print

print(list(map(lambda x:x**2, iterable)))  # you can print directly
# Out:
# <class 'map'>
# [1, 4, 9, 16, 25]
# [1, 4, 9, 16, 25]

# %%
iterable = [1, 2, 3, 4, 5]

result = map (lambda x : x**2, iterable)

# %%
print(result)

# %%
print(*result)
# Out:
# 1 4 9 16 25

# %%
def karasinial(x) :
    return x**2

# %%
iterable = [1, 2, 3, 4, 5]

# %%
result1 = map(karasinial, iterable)
print(list(result1))
# Out:
# [1, 4, 9, 16, 25]

# %%
iterabe_2 = ['ahmed', 'mehmet ve kuzeni', 'cemilin bacisi']

# %%
result_2 = map(len, iterabe_2) ## her bir elemanina uygular

# %%
print(*result_2)##ahmed 5,
# Out:
# 5 16 14

# %%
letter1 = ['o', 's', 't', 't']
letter2 = ['n', 'i', 'e', 'w']
letter3 = ['e', 'x', 'n', 'o']
numbers = map(lambda x, y, z: x+y+z, letter1, letter2, letter3) ## bir fonksiyon var,
## birden fazla iterable alabilir

print(list(numbers))
# Out:
# ['one', 'six', 'ten', 'two']

# %%
letter1 = ['a', 'b', 'c']
letter2 = ['x', 'y', 'z']

# %%
yapistir = map(zip, letter1, letter2)

# %%
for i in yapistir:
    print(i)

# %%
for i in yapistir:
    for j in i:
        print(j)
# Out:
# ('a', 'x')
# ('b', 'y')
# ('c', 'z')
