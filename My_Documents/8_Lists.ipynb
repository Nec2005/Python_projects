# %%
country = ['Turkey', 'Greece', 'England', 'USA', 'Brasil', 'Italy'] # Value , type ise list

country.append('France')
country.insert(3, 'Netherland')
print(country)
# Out:
# ['Turkey', 'Greece', 'England', 'Netherland', 'USA', 'Brasil', 'Italy', 'France']

# %%
list1 = ['anka', 'kus', 'kedi']
list1.append('miyav')
list1.insert(2, 'kek')
list1
# Out:
# ['anka', 'kus', 'kek', 'kedi', 'miyav']

# %%
text = 'I am learning Python'
list1 = list(text)  # stringin her bir elemani bir deger icine aliniyor
print(list1)

list2 = [text]
print(list2)
# Out:
# ['I', ' ', 'a', 'm', ' ', 'l', 'e', 'a', 'r', 'n', 'i', 'n', 'g', ' ', 'P', 'y', 't', 'h', 'o', 'n']
# ['I am learning Python']

# %%
text = 'I am learning Python'

print(list(text))

print([text])
# Out:
# ['I', ' ', 'a', 'm', ' ', 'l', 'e', 'a', 'r', 'n', 'i', 'n', 'g', ' ', 'P', 'y', 't', 'h', 'o', 'n']
# ['I am learning Python']

# %%
list_1 = ['h', 'a', 'p', 'p', 'y']
word = 'happy'
list_2 = list(word)  # elemalarini boler, listenin elemani haline gitirir
print(list_1)
print(list_2)
# Out:
# ['h', 'a', 'p', 'p', 'y']
# ['h', 'a', 'p', 'p', 'y']

# %%
new = [word] #degeri n ise o doner
new
# Out:
# ['happy']

# %%
mixed_list = [23, 'Ali', False, 3.14, None, [1,2,3]] # liste icinde farkli veriler saklayabilirsniz

# %%
my_list = ['Joseph', 'Clarusway', 2020] # type list, bunun uc elemani var
new_list1 = list(my_list)
new_list2 = [my_list]   

print(new_list1)   # iterable verileri tek tek aliyor' liste yapar integer parcalanmaz
print(len(new_list1))
print(new_list2)
print(len(new_list2))
# Out:
# ['Joseph', 'Clarusway', 2020]
# 3
# [['Joseph', 'Clarusway', 2020]]
# 1

# %%
list(112)    # string arar, iterab eolmasi icin
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-87e2187af33a> in <module>()
# ----> 1 list(112)
#
# TypeError: 'int' object is not iterable

# %%
list('112')
# Out:
# ['1', '1', '2']

# %%
a = '123pq-.,c67'
b = [a]
b
# Out:
# ['123pq-.,c67']

# %%
type(b)
# Out:
# list

# %%
a = ['Ali', 'Fatma', 123, 3.14]
a
# Out:
# ['Ali', 'Fatma', 123, 3.14]

# %%
b = [a]
print(b)
len(b)
# Out:
# [['Ali', 'Fatma', 123, 3.14]]
# 1

# %%
text = "2020's hard"
print(list(text))
print([text])
# Out:
# ['2', '0', '2', '0', "'", 's', ' ', 'h', 'a', 'r', 'd']
# ["2020's hard"]

# %%
numbers =[1, 4, 7]  #listeleri methodla degistiriyoruz. Stringler degismez stringler immutable.listeler mutable
numbers.append(9)
numbers.append('9') 
print(numbers)
# Out:
# [1, 4, 7, 9, '9']

# %%
cc= [22]
cc.append('34')
cc
# Out:
# [22, '34']

# %%
list_1 = []
list_1.append(1)
list_1.append(2)
list_1.append(3)
list_1.append(4)
print(list_1)
# Out:
# [1, 2, 3, 4]

# %%
numbers = [1, 4, 7]
numbers.insert(2, True) # 2.index e  elemanina koy demek
print(numbers)
numbers.insert(2, 6) # yeni olusan listenin 2. indexine 6 elemanini koy
print(numbers)
# Out:
# [1, 4, True, 7]
# [1, 4, 6, True, 7]

# %%
city = ['los', 'beirut', 'tokyo']
city[0] = True  # los gider yerine True gelir. 0. eleman
city
# Out:
# [True, 'beirut', 'tokyo']

# %%
city = ['los', 'beirut', 'tokyo']
city
# Out:
# ['los', 'beirut', 'tokyo']

# %%
city[1:] = 'clarus' # 1. indexten itibaren elemanalrina ayirdi listenin sonuna kadar gider
city
# Out:
# [True, 'c', 'l', 'a', 'r', 'u', 's']

# %%
city
# Out:
# [True, 'c', 'l', 'a', 'r', 'u', 's']

# %%
city
# Out:
# ['los', 'beirut', 'tokyo']

# %%
city[1:] = "istanbul", "seul" # iki elemani oldugu icin tek basina iterable
city
# Out:
# ['los', 'istanbul', 'seul']

# %%
city1 = ['istabul', 'yozgat', 'erzurum', 'ankara']
city1
# Out:
# ['istabul', 'yozgat', 'erzurum', 'ankara']

# %%
city1[0:2] = ['a', 'b', 'c', 'd'] #0. ve 1. indexlere yeni eleman atadi
city1
# Out:
# ['a', 'b', 'c', 'd', 'c', 'erzurum', 'ankara']

# %%
city1[0:2] = 'a'
city1
# Out:
# ['a', 'erzurum', 'ankara']

# %%
city1[0:2] = 'abc'
city1
# Out:
# ['a', 'b', 'c', 'erzurum', 'ankara']

# %%
list_1 = ['h', 'a', 'p', 'p', 'y']
word = 'happy'
list_2 = list(word)

# %%
list_1
# Out:
# ['h', 'a', 'p', 'p', 'y']

# %%
list_2
# Out:
# ['h', 'a', 'p', 'p', 'y']

# %%
list()

# %%
list_3 = ['happy']
word
# Out:
# 'happy'

# %%
type(list_3)
# Out:
# list

# %%
list_4 = ["ben bu dersi dinlayince cok rahatliyorum"]

# %%
list_5 = list(list_3)
list_5
# Out:
# ['happy']

# %%
list_6 = list(list_2)

# %%
a = ["23$%6asfsg^&7*-+*"]
len(a)
# Out:
# 1

# %%
my_list = ['Joseph', 'Clarusway', 2020]
new_list1 = list(my_list)
new_list2 = [my_list]
new_list1
# Out:
# ['Joseph', 'Clarusway', 2020]

# %%
new_list2
# Out:
# [['Joseph', 'Clarusway', 2020]]

# %%
text = "2020's hard"
list(text)
# Out:
# ['2', '0', '2', '0', "'", 's', ' ', 'h', 'a', 'r', 'd']

# %%
yy = ['ali']

yy[::-1]
# Out:
# ['ali']

# %%
list1 = []
list1.append(1)
list1.append(2)
list1.append(3)
list1
# Out:
# [1, 2, 3]

# %%
sayilar = [1, 4, 7]
sayilar.insert(20, 9)
sayilar
# Out:
# [1, 4, 7, 9]

# %%
ord('a')
# Out:
# 97

# %%
ord('A')
# Out:
# 65
